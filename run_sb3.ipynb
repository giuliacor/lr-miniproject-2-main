# %%
# !nvidia-smi
# Out:
# Fri Nov 21 16:15:38 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install stable-baselines3[extra] gymnasium pybullet numpy==1.26.4

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("Device:", torch.device("cuda" if torch.cuda.is_available() else "CPU"))
# Out:
# CUDA available: True
# Device: cuda

# %%
# !git clone https://github.com/giuliacor/lr-miniproject-2-main.git
# %cd lr-miniproject-2-main
# !git branch -a
# Out:
# Cloning into 'lr-miniproject-2-main'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 67 (delta 23), reused 57 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (67/67), 5.74 MiB | 12.34 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# /content/lr-miniproject-2-main
# * main
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/gc
#   remotes/origin/jb
#   remotes/origin/main
#   remotes/origin/sz

# %%
# !git checkout jb
# Out:
# Branch 'jb' set up to track remote branch 'jb' from 'origin'.
# Switched to a new branch 'jb'

# %%
# %run run_sb3.py
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /content/lr-miniproject-2-main/run_sb3.py in <module>
#      11
#      12 # stable baselines 3
# ---> 13 from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
#      14 from stable_baselines3 import PPO, SAC
#      15 from stable_baselines3.common.env_util import make_vec_env
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/__init__.py in <module>
#       1 import os
#       2
# ----> 3 from stable_baselines3.a2c import A2C
#       4 from stable_baselines3.common.utils import get_system_info
#       5 from stable_baselines3.ddpg import DDPG
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/a2c/__init__.py in <module>
# ----> 1 from stable_baselines3.a2c.a2c import A2C
#       2 from stable_baselines3.a2c.policies import CnnPolicy, MlpPolicy, MultiInputPolicy
#       3
# ...
