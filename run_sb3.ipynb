# %%
# !nvidia-smi
# Out:
# Fri Nov 21 17:33:59 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install "stable-baselines3[extra]" "gymnasium>=1.0.0" pybullet

# %%
# !rm -rf lr-miniproject-2-main
# !git clone https://github.com/giuliacor/lr-miniproject-2-main.git
# %cd lr-miniproject-2-main
# !git checkout jb
# Out:
# Cloning into 'lr-miniproject-2-main'...
# remote: Enumerating objects: 79, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 79 (delta 31), reused 65 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (79/79), 5.75 MiB | 23.07 MiB/s, done.
# Resolving deltas: 100% (31/31), done.
# /content/lr-miniproject-2-main/lr-miniproject-2-main/lr-miniproject-2-main
# Branch 'jb' set up to track remote branch 'jb' from 'origin'.
# Switched to a new branch 'jb'

# %%
# %run run_sb3.py
# Out:
# Using cuda device
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 294      |
# |    ep_rew_mean     | 0.00734  |
# | time/              |          |
# |    fps             | 155      |
# |    iterations      | 1        |
# |    time_elapsed    | 26       |
# |    total_timesteps | 4096     |
# ---------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 389         |
# |    ep_rew_mean          | 0.00547     |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 2           |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016056519 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | -15         |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00326     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0265     |
# |    std                  | 1           |
# |    value_loss           | 0.0149      |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 415         |
# |    ep_rew_mean          | 0.00578     |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 3           |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.016234806 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | -3.39       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0354     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0275     |
# |    std                  | 1           |
# |    value_loss           | 0.0042      |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 398         |
# |    ep_rew_mean          | 0.00487     |
# | time/                   |             |
# |    fps                  | 157         |
# |    iterations           | 4           |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.016089251 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | -4.84       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0292     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0273     |
# |    std                  | 0.998       |
# |    value_loss           | 0.00269     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 421         |
# |    ep_rew_mean          | 0.00598     |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 5           |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.015662763 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | -6.06       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0277     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0267     |
# |    std                  | 0.997       |
# |    value_loss           | 0.002       |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 419         |
# |    ep_rew_mean          | 0.00653     |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 6           |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.017347947 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | -5.23       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0387     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0296     |
# |    std                  | 0.997       |
# |    value_loss           | 0.00149     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 421         |
# |    ep_rew_mean          | 0.006       |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 7           |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015909303 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | -7.11       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.053      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0276     |
# |    std                  | 0.999       |
# |    value_loss           | 0.00122     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# Saving model checkpoint to ./logs/intermediate_models/112125181614/rl_model_30000_steps
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 431        |
# |    ep_rew_mean          | 0.00573    |
# | time/                   |            |
# |    fps                  | 158        |
# |    iterations           | 8          |
# |    time_elapsed         | 206        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01733765 |
# |    clip_fraction        | 0.184      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -17        |
# |    explained_variance   | -11.2      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0306    |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0311    |
# |    std                  | 0.998      |
# |    value_loss           | 0.000968   |
# ----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 434         |
# |    ep_rew_mean          | 0.00548     |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 9           |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.016444178 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | -14.8       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0112     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.028      |
# |    std                  | 1           |
# |    value_loss           | 0.000773    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 434        |
# |    ep_rew_mean          | 0.00565    |
# | time/                   |            |
# |    fps                  | 157        |
# |    iterations           | 10         |
# |    time_elapsed         | 260        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.01630272 |
# |    clip_fraction        | 0.172      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -17        |
# |    explained_variance   | -12.3      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.000441   |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.028     |
# |    std                  | 1          |
# |    value_loss           | 0.000701   |
# ----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 430         |
# |    ep_rew_mean          | 0.00578     |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 11          |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.017180141 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | -10.8       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0524     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.029      |
# |    std                  | 0.998       |
# |    value_loss           | 0.000529    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 430         |
# |    ep_rew_mean          | 0.00599     |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 12          |
# |    time_elapsed         | 316         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.015552674 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | -15.7       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.029      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0277     |
# |    std                  | 0.998       |
# |    value_loss           | 0.000455    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 421         |
# |    ep_rew_mean          | 0.00625     |
# | time/                   |             |
# |    fps                  | 154         |
# |    iterations           | 13          |
# |    time_elapsed         | 345         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.016350642 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | -19.6       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0364     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0294     |
# |    std                  | 0.995       |
# |    value_loss           | 0.000366    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 413        |
# |    ep_rew_mean          | 0.00635    |
# | time/                   |            |
# |    fps                  | 154        |
# |    iterations           | 14         |
# |    time_elapsed         | 372        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.01700411 |
# |    clip_fraction        | 0.183      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -17        |
# |    explained_variance   | -24.2      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.00473   |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0288    |
# |    std                  | 0.994      |
# |    value_loss           | 0.000324   |
# ----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# Saving model checkpoint to ./logs/intermediate_models/112125181614/rl_model_60000_steps
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 403         |
# |    ep_rew_mean          | 0.00623     |
# | time/                   |             |
# |    fps                  | 154         |
# |    iterations           | 15          |
# |    time_elapsed         | 397         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.016552418 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -16.9       |
# |    explained_variance   | -9.3        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0516     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0297     |
# |    std                  | 0.993       |
# |    value_loss           | 0.000289    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 415         |
# |    ep_rew_mean          | 0.00596     |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 16          |
# |    time_elapsed         | 422         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.017461501 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -16.9       |
# |    explained_variance   | -16.1       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0424     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0316     |
# |    std                  | 0.993       |
# |    value_loss           | 0.000251    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 403         |
# |    ep_rew_mean          | 0.00626     |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 17          |
# |    time_elapsed         | 448         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.017597971 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -16.9       |
# |    explained_variance   | -22.3       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0389     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0312     |
# |    std                  | 0.991       |
# |    value_loss           | 0.000241    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 405        |
# |    ep_rew_mean          | 0.00618    |
# | time/                   |            |
# |    fps                  | 155        |
# |    iterations           | 18         |
# |    time_elapsed         | 474        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.01702716 |
# |    clip_fraction        | 0.185      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -16.9      |
# |    explained_variance   | -26.4      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0319    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0305    |
# |    std                  | 0.99       |
# |    value_loss           | 0.000213   |
# ----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 408         |
# |    ep_rew_mean          | 0.00598     |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 19          |
# |    time_elapsed         | 499         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.018002335 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -16.9       |
# |    explained_variance   | -24.7       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0498     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0318     |
# |    std                  | 0.987       |
# |    value_loss           | 0.00018     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 408         |
# |    ep_rew_mean          | 0.00597     |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 20          |
# |    time_elapsed         | 525         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.016297027 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -16.9       |
# |    explained_variance   | -25.5       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0194     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0279     |
# |    std                  | 0.984       |
# |    value_loss           | 0.000155    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 412         |
# |    ep_rew_mean          | 0.00565     |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 21          |
# |    time_elapsed         | 551         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.016984355 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -16.8       |
# |    explained_variance   | -13.8       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0301     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0299     |
# |    std                  | 0.984       |
# |    value_loss           | 0.000144    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# Saving model checkpoint to ./logs/intermediate_models/112125181614/rl_model_90000_steps
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 417         |
# |    ep_rew_mean          | 0.00533     |
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 22          |
# |    time_elapsed         | 577         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.019798744 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -16.8       |
# |    explained_variance   | -11.5       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.055      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0332     |
# |    std                  | 0.983       |
# |    value_loss           | 0.000128    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 410         |
# |    ep_rew_mean          | 0.00508     |
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 23          |
# |    time_elapsed         | 603         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.018314078 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -16.8       |
# |    explained_variance   | -23.8       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0325     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0332     |
# |    std                  | 0.982       |
# |    value_loss           | 0.000117    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 411         |
# |    ep_rew_mean          | 0.00498     |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 24          |
# |    time_elapsed         | 630         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.017475221 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -16.8       |
# |    explained_variance   | -21.8       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.042      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0313     |
# |    std                  | 0.982       |
# |    value_loss           | 0.000118    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 414         |
# |    ep_rew_mean          | 0.00437     |
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 25          |
# |    time_elapsed         | 656         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.015843306 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -16.8       |
# |    explained_variance   | -12.6       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0245     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0275     |
# |    std                  | 0.983       |
# |    value_loss           | 9.81e-05    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 403         |
# |    ep_rew_mean          | 0.00434     |
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 26          |
# |    time_elapsed         | 681         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.017720912 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -16.8       |
# |    explained_variance   | -20.4       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0395     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.031      |
# |    std                  | 0.98        |
# |    value_loss           | 9.83e-05    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 394         |
# |    ep_rew_mean          | 0.00483     |
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 27          |
# |    time_elapsed         | 708         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.017329436 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -16.8       |
# |    explained_variance   | -23.5       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0365     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0307     |
# |    std                  | 0.981       |
# |    value_loss           | 9.14e-05    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 385         |
# |    ep_rew_mean          | 0.00488     |
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 28          |
# |    time_elapsed         | 733         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.018122863 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -16.8       |
# |    explained_variance   | -12.9       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.01       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.031      |
# |    std                  | 0.98        |
# |    value_loss           | 8.38e-05    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# ----------------------------------------
# ...
# |    total_timesteps      | 966656      |
# | train/                  |             |
# |    approx_kl            | 0.021649275 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -12.6       |
# |    explained_variance   | 0.676       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0283     |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | -0.0449     |
# |    std                  | 0.694       |
# |    value_loss           | 0.107       |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 790         |
# |    ep_rew_mean          | 25          |
# | time/                   |             |
# |    fps                  | 163         |
# |    iterations           | 237         |
# |    time_elapsed         | 5928        |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.020012852 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -12.6       |
# |    explained_variance   | 0.499       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0294     |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.0437     |
# |    std                  | 0.692       |
# |    value_loss           | 0.0863      |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 797        |
# |    ep_rew_mean          | 25.4       |
# | time/                   |            |
# |    fps                  | 163        |
# |    iterations           | 238        |
# |    time_elapsed         | 5952       |
# |    total_timesteps      | 974848     |
# | train/                  |            |
# |    approx_kl            | 0.02088169 |
# |    clip_fraction        | 0.259      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -12.5      |
# |    explained_variance   | 0.712      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.000929   |
# |    n_updates            | 2370       |
# |    policy_gradient_loss | -0.0423    |
# |    std                  | 0.69       |
# |    value_loss           | 0.12       |
# ----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 796        |
# |    ep_rew_mean          | 25.5       |
# | time/                   |            |
# |    fps                  | 163        |
# |    iterations           | 239        |
# |    time_elapsed         | 5975       |
# |    total_timesteps      | 978944     |
# | train/                  |            |
# |    approx_kl            | 0.02289724 |
# |    clip_fraction        | 0.268      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -12.5      |
# |    explained_variance   | 0.648      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.00107   |
# |    n_updates            | 2380       |
# |    policy_gradient_loss | -0.0437    |
# |    std                  | 0.689      |
# |    value_loss           | 0.122      |
# ----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 813         |
# |    ep_rew_mean          | 26.2        |
# | time/                   |             |
# |    fps                  | 163         |
# |    iterations           | 240         |
# |    time_elapsed         | 5997        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.020175982 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -12.5       |
# |    explained_variance   | 0.563       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00948    |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.0413     |
# |    std                  | 0.687       |
# |    value_loss           | 0.102       |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 822         |
# |    ep_rew_mean          | 26.9        |
# | time/                   |             |
# |    fps                  | 163         |
# |    iterations           | 241         |
# |    time_elapsed         | 6020        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.022612909 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -12.5       |
# |    explained_variance   | 0.436       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0242     |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | -0.0466     |
# |    std                  | 0.686       |
# |    value_loss           | 0.0886      |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# Saving model checkpoint to ./logs/intermediate_models/112125181614/rl_model_990000_steps
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 838         |
# |    ep_rew_mean          | 27.9        |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 242         |
# |    time_elapsed         | 6043        |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.020360164 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.533       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00381    |
# |    n_updates            | 2410        |
# |    policy_gradient_loss | -0.0406     |
# |    std                  | 0.685       |
# |    value_loss           | 0.101       |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 853         |
# |    ep_rew_mean          | 28.9        |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 243         |
# |    time_elapsed         | 6067        |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.021953855 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.36        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0254     |
# |    n_updates            | 2420        |
# |    policy_gradient_loss | -0.0428     |
# |    std                  | 0.684       |
# |    value_loss           | 0.0881      |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 860       |
# |    ep_rew_mean          | 29.5      |
# | time/                   |           |
# |    fps                  | 164       |
# |    iterations           | 244       |
# |    time_elapsed         | 6089      |
# |    total_timesteps      | 999424    |
# | train/                  |           |
# |    approx_kl            | 0.0193043 |
# |    clip_fraction        | 0.267     |
# |    clip_range           | 0.2       |
# |    clip_range_vf        | 1         |
# |    entropy_loss         | -12.4     |
# |    explained_variance   | 0.581     |
# |    learning_rate        | 0.0001    |
# |    loss                 | -0.0217   |
# |    n_updates            | 2430      |
# |    policy_gradient_loss | -0.0408   |
# |    std                  | 0.683     |
# |    value_loss           | 0.0905    |
# ---------------------------------------
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# =================================== Save path is ./logs/intermediate_models/112125181614/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 857         |
# |    ep_rew_mean          | 29.9        |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 245         |
# |    time_elapsed         | 6113        |
# |    total_timesteps      | 1003520     |
# | train/                  |             |
# |    approx_kl            | 0.023154099 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -12.4       |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0433     |
# |    n_updates            | 2440        |
# |    policy_gradient_loss | -0.0458     |
# |    std                  | 0.682       |
# |    value_loss           | 0.0979      |
# -----------------------------------------
